# %% [markdown]
# # Obtenido de Mining the Social Web, 2nd Edition
#
# ## Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'e0fqUPjVpjmrqj3ekNddmMRvK'
CONSUMER_SECRET ='y3NeMgtvtqGrw2CButmLa331pfiHInLH3GXltVIHYHMVsG2BBO'
OAUTH_TOKEN = '1559294270-igXLs7yXVCVfQ0JpahnxZt86zV8nB2ribNoRwCC'
OAUTH_TOKEN_SECRET = 'iA5H36ROJJVtR6vl9tHygXQlsAzFAfnkK4EpA9o9kcesd'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x10a8777f0>

# %%
# !pip3 install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
#     100% |████████████████████████████████| 61kB 1.1MB/s ta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.17.1

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
print(us_trends)
# Out:
# [{'trends': [{'name': '#SWISHSWISH', 'url': 'http://twitter.com/search?q=%23SWISHSWISH', 'promoted_content': None, 'query': '%23SWISHSWISH', 'tweet_volume': 87012}, {'name': '#BuyCryingInTheClubOniTunes', 'url': 'http://twitter.com/search?q=%23BuyCryingInTheClubOniTunes', 'promoted_content': None, 'query': '%23BuyCryingInTheClubOniTunes', 'tweet_volume': 107913}, {'name': '#StripThatDown', 'url': 'http://twitter.com/search?q=%23StripThatDown', 'promoted_content': None, 'query': '%23StripThatDown', 'tweet_volume': 164187}, {'name': '#Scandal', 'url': 'http://twitter.com/search?q=%23Scandal', 'promoted_content': None, 'query': '%23Scandal', 'tweet_volume': 116431}, {'name': '#Vertigo2017', 'url': 'http://twitter.com/search?q=%23Vertigo2017', 'promoted_content': None, 'query': '%23Vertigo2017', 'tweet_volume': 11267}, {'name': 'Botafogo', 'url': 'http://twitter.com/search?q=Botafogo', 'promoted_content': None, 'query': 'Botafogo', 'tweet_volume': 88097}, {'name': '윤석열', 'url': 'http://twitter.com/search?q=%EC%9C%A
query': '%22Santa+Cos%22', 'tweet_volume': None}, {'name': 'Velazquez', 'url': 'http://twitter.com/search?q=Velazquez', 'promoted_content': None, 'query': 'Velazquez', 'tweet_volume': None}, {'name': 'Sonny Gray', 'url': 'http://twitter.com/search?q=%22Sonny+Gray%22', 'promoted_content': None, 'query': '%22Sonny+Gray%22', 'tweet_volume': None}, {'name': 'Jose Berrios', 'url': 'http://twitter.com/search?q=%22Jose+Berrios%22', 'promoted_content': None, 'query': '%22Jose+Berrios%22', 'tweet_volume': None}, {'name': 'Chris Taylor', 'url': 'http://twitter.com/search?q=%22Chris+Taylor%22', 'promoted_content': None, 'query': '%22Chris+Taylor%22', 'tweet_volume': None}, {'name': '#CarpoolHarryoke', 'url': 'http://twitter.com/search?q=%23CarpoolHarryoke', 'promoted_content': None, 'query': '%23CarpoolHarryoke', 'tweet_volume': 36876}, {'name': '#GreysAnatomy', 'url': 'http://twitter.com/search?q=%23GreysAnatomy', 'promoted_content': None, 'query': '%23GreysAnatomy', 'tweet_volume': 95782}, {'name': '#RipTempo', 'url': 'http://twitter.com/search?q=%23RipTempo', 'promoted_content': None, 'query': '%23RipTempo', 'tweet_volume': None}, {'name': '#Supernatural', 'url': 'http://twitter.com/search?q=%23Supernatural ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print(json.dumps(world_trends, indent=1))
print
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#SWISHSWISH",
#     "url": "http://twitter.com/search?q=%23SWISHSWISH",
#     "promoted_content": null,
#     "query": "%23SWISHSWISH",
#     "tweet_volume": 87012
#    },
#    {
#     "name": "#BuyCryingInTheClubOniTunes",
#     "url": "http://twitter.com/search?q=%23BuyCryingInTheClubOniTunes",
#     "promoted_content": null,
#     "query": "%23BuyCryingInTheClubOniTunes",
#     "tweet_volume": 107913
#    },
#    {
#     "name": "#StripThatDown",
#     "url": "http://twitter.com/search?q=%23StripThatDown",
#     "promoted_content": null,
#     "query": "%23StripThatDown",
#     "tweet_volume": 164187
#    },
#    {
#     "name": "#Scandal",
#     "url": "http://twitter.com/search?q=%23Scandal",
#     "promoted_content": null,
#     "query": "%23Scandal",
#     "tweet_volume": 116431
#    },
#    {
#     "name": "#Vertigo2017",
#     "url": "http://twitter.com/search?q=%23Vertigo2017",
#     "promoted_content": null,
#     "query": "%23Vertigo2017",
#     "tweet_volume": 11267
#    },
#    {
#     "name": "Botafogo",
#     "url": "http://twitter.com/search?q=Botafogo",
#     "promoted_content": null,
#     "query": "Botafogo",
#     "tweet_volume": 88097
#    },
#    {
#     "name": "\uc724\uc11d\uc5f4",
#     "url": "http://twitter.com/search?q=%EC%9C%A4%EC%84%9D%EC%97%B4",
#     "promoted_content": null,
#     "query": "%EC%9C%A4%EC%84%9D%EC%97%B4",
#     "tweet_volume": 23589
#    },
#    {
#     "name": "Xolos",
#     "url": "http://twitter.com/search?q=Xolos",
#     "promoted_content": null,
#     "query": "Xolos",
#     "tweet_volume": 17263
#    },
#    {
#     "name": "\u5f37\u884c\u63a1\u6c7a",
#     "url": "http://twitter.com/search?q=%E5%BC%B7%E8%A1%8C%E6%8E%A1%E6%B1%BA",
#     "promoted_content": null,
#     "query": "%E5%BC%B7%E8%A1%8C%E6%8E%A1%E6%B1%BA",
#     "tweet_volume": 44155
#    },
#    {
#     "name": "\uc724\uc11d\ub82c",
#     "url": "http://twitter.com/search?q=%EC%9C%A4%EC%84%9D%EB%A0%AC",
#     "promoted_content": null,
#     "query": "%EC%9C%A4%EC%84%9D%EB%A0%AC",
#     "tweet_volume": 12709
#    },
#    {
#     "name": "\u5b9d\u77f3\u306e\u56fd",
#     "url": "http://twitter.com/search?q=%E5%AE%9D%E7%9F%B3%E3%81%AE%E5%9B%BD",
#     "promoted_content": null,
#     "query": "%E5%AE%9D%E7%9F%B3%E3%81%AE%E5%9B%BD",
#     "tweet_volume": 26340
#    },
#    {
#     "name": "Mayada",
#     "url": "http://twitter.com/search?q=Mayada",
#     "promoted_content": null,
#     "query": "Mayada",
#     "tweet_volume": 22465
#    },
#    {
#     "name": "Toluca",
#     "url": "http://twitter.com/search?q=Toluca",
#     "promoted_content": null,
#     "query": "Toluca",
#     "tweet_volume": 27072
#    },
#    {
#     "name": "Car Boys",
#     "url": "http://twitter.com/search?q=%22Car+Boys%22",
#     "promoted_content": null,
#     "query": "%22Car+Boys%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ruby Rose",
#     "url": "http://twitter.com/search?q=%22Ruby+Rose%22",
#     "promoted_content": null,
#     "query": "%22Ruby+Rose%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NSFW90sShows",
#     "url": "http://twitter.com/search?q=%23NSFW90sShows",
#     "promoted_content": null,
#     "query": "%23NSFW90sShows",
#     "tweet_volume": 18943
#    },
#    {
#     "name": "#AddaElFinal",
#     "url": "http://twitter.com/search?q=%23AddaElFinal",
#     "promoted_content": null,
#     "query": "%23AddaElFinal",
#     "tweet_volume": 27911
#    },
#    {
#     "name": "#CarpoolHarryoke",
#     "url": "http://twitter.com/search?q=%23CarpoolHarryoke",
#     "promoted_content": null,
#     "query": "%23CarpoolHarryoke",
#     "tweet_volume": 36876
#    },
#    {
#     "name": "#Supernatural",
#     "url": "http://twitter.com/search?q=%23Supernatural",
#     "promoted_content": null,
#     "query": "%23Supernatural",
#     "tweet_volume": 125418
#    },
#    {
#     "name": "#bucciovertimechallenge",
#     "url": "http://twitter.com/search?q=%23bucciovertimechallenge",
#     "promoted_content": null,
#     "query": "%23bucciovertimechallenge",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GreysAnatomy",
#     "url": "http://twitter.com/search?q=%23GreysAnatomy",
#     "promoted_content": null,
#     "query": "%23GreysAnatomy",
#     "tweet_volume": 95782
#    },
#    {
#     "name": "#LaVenganza",
#     "url": "http://twitter.com/search?q=%23LaVenganza",
#     "promoted_content": null,
#     "query": "%23LaVenganza",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RipTempo",
#     "url": "http://twitter.com/search?q=%23RipTempo",
#     "promoted_content": null,
#     "query": "%23RipTempo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EsLeyQueBorracho",
#     "url": "http://twitter.com/search?q=%23EsLeyQueBorracho",
#     "promoted_content": null,
#     "query": "%23EsLeyQueBorracho",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0643\u062b\u0631_\u0634\u064a_\u064a\u0631\u0648\u0642\u0646\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%83%D8%AB%D8%B1_%D8%B4%D9%8A_%D9%8A%D8%B1%D9%88%D9%82%D9%86%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%
#     "promoted_content": null,
#     "query": "%23%E8%A8%80%E3%81%86%E3%81%A0%E3%81%91%E3%82%BF%E3%83%80%E3%81%A0%E3%81%8B%E3%82%89%E6%AC%B2%E3%81%97%E3%81%84%E3%82%A2%E3%83%B3%E3%82%BD%E3%83%AD%E5%91%9F%E3%81%8F",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ANAvsNSH",
#     "url": "http://twitter.com/search?q=%23ANAvsNSH",
#     "promoted_content": null,
#     "query": "%23ANAvsNSH",
#     "tweet_volume": 11954
#    },
#    {
#     "name": "#ElTrato",
#     "url": "http://twitter.com/search?q=%23ElTrato",
#     "promoted_content": null,
#     "query": "%23ElTrato",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0643\u062b\u0631_\u062d\u0627\u062c\u0647_\u062a\u0632\u0639\u0644\u0646\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%83%D8%AB%D8%B1_%D8%AD%D8%A7%D8%AC%D9%87_%D8%AA%D8%B2%D8%B9%D9%84%D9%86%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%83%D8%AB%D8%B1_%D8%AD%D8%A7%D8%AC%D9%87_%D8%AA%D8%B2%D8%B9%D9%84%D9%86%D9%8A",
#     "tweet_volume": 56350
#    },
#    {
#     "name": "#\ub098\ub294\uc5b4\ub5a4\ub9db",
#     "url": "http://twitter.com/search?q=%23%EB%82%98%EB%8A%94%EC%96%B4%EB%96%A4%EB%A7%9B",
#     "promoted_content": null,
#     "query": "%23%EB%82%98%EB%8A%94%EC%96%B4%EB%96%A4%EB%A7%9B",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BuySwitchOniTunes",
#     "url": "http://twitter.com/search?q=%23BuySwitchOniTunes",
#     "promoted_content": null,
#     "query": "%23BuySwitchOniTunes",
#     "tweet_volume": 26973
#    },
#    {
#     "name": "#\u6b7b\u4ea1\u304b\u3089\u4e88\u6e2c\u5909\u63db\u3067\u751f\u9084\u3081\u3056\u3059",
#     "url": "http://twitter.com/search?q=%23%E6%AD%BB%E4%BA%A1%E3%81%8B%E3%82%89%E4%BA%88%E6%B8%AC%E5%A4%89%E6%8F%9B%E3%81%A7%E7%94%9F%E9%82%84%E3%82%81%E3%81%96%E3%81%99",
#     "promoted_content": null,
#     "query": "%23%E6%AD%BB%E4%BA%A1%E3%81%8B%E3%82%89%E4%BA%88%E6%B8%AC%E5%A4%89%E6%8F%9B%E3%81%A7%E7%94%9F%E9%82%84%E3%82%81%E3%81%96%E3%81%99",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JumatBerkah",
#     "url": "http://twitter.com/search?q=%23JumatBerkah",
#     "promoted_content": null,
#     "query": "%23JumatBerkah",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MaiaraeMaraisaNoBial",
#     "url": "http://twitter.com/search?q=%23MaiaraeMaraisaNoBial",
#     "promoted_content": null,
#     "query": "%23MaiaraeMaraisaNoBial",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InsteadOfComplaining",
#     "url": "http://twitter.com/search?q=%23InsteadOfComplaining",
#     "promoted_content": null,
#     "query": "%23InsteadOfComplaining",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UnidosPeloSPFC",
#     "url": "http://twitter.com/search?q=%23UnidosPeloSPFC",
#     "promoted_content": null,
#     "query": "%23UnidosPeloSPFC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ProgramaDoPorchat",
#     "url": "http://twitter.com/search?q=%23ProgramaDoPorchat",
#     "promoted_content": null,
#     "query": "%23ProgramaDoPorchat",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0644\u0645\u0641\u0642\u0648\u062f\u0647_\u0637\u064a\u0628\u0647_\u0645\u062d\u0645\u0648\u062f_\u0627\u0644_\u062c\u0627\u0633\u0645",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D9%81%D9%82%D9%88%D8%AF%D9%87_%D8%B7%D9%8A%D8%A8%D9%87_%D9%85%D8%AD%D9%85%D9%88%D8%AF_%D8%A7%D9%84_%D8%AC%D8%A7%D8%B3%D9%85",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D9%85%D9%81%D9%82%D9%88%D8%AF%D9%87_%D8%B7%D9%8A%D8%A8%D9%87_%D9%85%D8%AD%D9%85%D9%88%D8%AF_%D8%A7%D9%84_%D8%AC%D8%A7%D8%B3%D9%85",
#     "tweet_volume": 310072
#    },
#    {
#     "name": "#VictoriousFinale",
#     "url": "http://twitter.com/search?q=%23VictoriousFinale",
#     "promoted_content": null,
#     "query": "%23VictoriousFinale",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MafiaSdvSegueQTeSigo",
#     "url": "http://twitter.com/search?q=%23MafiaSdvSegueQTeSigo",
#     "promoted_content": null,
#     "query": "%23MafiaSdvSegueQTeSigo",
#     "tweet_volume": 14110
#    },
#    {
#     "name": "#WelcomeToArgentinaEd",
#     "url": "http://twitter.com/search?q=%23WelcomeToArgentinaEd",
#     "promoted_content": null,
#     "query": "%23WelcomeToArgentinaEd",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HelpMeHelpYouOutNow",
#     "url": "http://twitter.com/search?q=%23HelpMeHelpYouOutNow",
#     "promoted_content": null,
#     "query": "%23HelpMeHelpYouOutNow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TwitterDown",
#     "url": "http://twitter.com/search?q=%23TwitterDown",
#     "promoted_content": null,
#     "query": "%23TwitterDown",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LoveForZayn",
#     "url": "http://twitter.com/search?q=%23LoveForZayn",
#     "promoted_content": null,
#     "query": "%23LoveForZayn",
#     "tweet_volume": 21576
#    },
#    {
#     "name": "#TheBlacklist",
#     "url": "http://twitter.com/search?q=%23TheBlacklist",
#     "promoted_content": null,
#     "query": "%23TheBlacklist",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-05-19T05:47:18Z",
#   "created_at": "2017-05-19T05:42:05Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "#Scandal",
#     "url": "http://twitter.com/search?q=%23Scandal",
#     "promoted_content": null,
#     "query": "%23Scandal",
#     "tweet_volume": 116431
#    },
#    {
#     "name": "#SwishSwish",
#     "url": "http://twitter.com/search?q=%23SwishSwish",
#     "promoted_content": null,
#     "query": "%23SwishSwish",
#     "tweet_volume": 87012
#    },
#    {
#     "name": "#StripThatDown",
#     "url": "http://twitter.com/search?q=%23StripThatDown",
#     "promoted_content": null,
#     "query": "%23StripThatDown",
#     "tweet_volume": 164187
#    },
#    {
#     "name": "#NSFW90sShows",
#     "url": "http://twitter.com/search?q=%23NSFW90sShows",
#     "promoted_content": null,
#     "query": "%23NSFW90sShows",
#     "tweet_volume": 18943
#    },
#    {
#     "name": "#BuyCryingInTheClubOniTunes",
#     "url": "http://twitter.com/search?q=%23BuyCryingInTheClubOniTunes",
#     "promoted_content": null,
#     "query": "%23BuyCryingInTheClubOniTunes",
#     "tweet_volume": 107913
#    },
#    {
#     "name": "Corey Perry",
#     "url": "http://twitter.com/search?q=%22Corey+Perry%22",
#     "promoted_content": null,
#     "query": "%22Corey+Perry%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Car Boys",
#     "url": "http://twitter.com/search?q=%22Car+Boys%22",
#     "promoted_content": null,
#     "query": "%22Car+Boys%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kenley Jansen",
#     "url": "http://twitter.com/search?q=%22Kenley+Jansen%22",
#     "promoted_content": null,
#     "query": "%22Kenley+Jansen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ruby Rose",
#     "url": "http://twitter.com/search?q=%22Ruby+Rose%22",
#     "promoted_content": null,
#     "query": "%22Ruby+Rose%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Justin Turner",
#     "url": "http://twitter.com/search?q=%22Justin+Turner%22",
#     "promoted_content": null,
#     "query": "%22Justin+Turner%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Basquiat",
#     "url": "http://twitter.com/search?q=Basquiat",
#     "promoted_content": null,
#     "query": "Basquiat",
#     "tweet_volume": 25710
#    },
#    {
#     "name": "Alien Covenant",
#     "url": "http://twitter.com/search?q=%22Alien+Covenant%22",
#     "promoted_content": null,
#     "query": "%22Alien+Covenant%22",
#     "tweet_volume": 15035
#    },
#    {
#     "name": "Matt Davidson",
#     "url": "http://twitter.com/search?q=%22Matt+Davidson%22",
#     "promoted_content": null,
#     "query": "%22Matt+Davidson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dan Altavilla",
#     "url": "http://twitter.com/search?q=%22Dan+Altavilla%22",
#     "promoted_content": null,
#     "query": "%22Dan+Altavilla%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Xolos",
#     "url": "http://twitter.com/search?q=Xolos",
#     "promoted_content": null,
#     "query": "Xolos",
#     "tweet_volume": 17263
#    },
#    {
#     "name": "Jarrod Dyson",
#     "url": "http://twitter.com/search?q=%22Jarrod+Dyson%22",
#     "promoted_content": null,
#     "query": "%22Jarrod+Dyson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "DCEU",
#     "url": "http://twitter.com/search?q=DCEU",
#     "promoted_content": null,
#     "query": "DCEU",
#     "tweet_volume": 10668
#    },
#    {
#     "name": "Santa Cos",
#     "url": "http://twitter.com/search?q=%22Santa+Cos%22",
#     "promoted_content": null,
#     "query": "%22Santa+Cos%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Velazquez",
#     "url": "http://twitter.com/search?q=Velazquez",
#     "promoted_content": null,
#     "query": "Velazquez",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sonny Gray",
#     "url": "http://twitter.com/search?q=%22Sonny+Gray%22",
#     "promoted_content": null,
#     "query": "%22Sonny+Gray%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jose Berrios",
#     "url": "http://twitter.com/search?q=%22Jose+Berrios%22",
#     "promoted_content": null,
#     "query": "%22Jose+Berrios%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chris Taylor",
#     "url": "http://twitter.com/search?q=%22Chris+Taylor%22",
#     "promoted_content": null,
#     "query": "%22Chris+Taylor%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CarpoolHarryoke",
#     "url": "http://twitter.com/search?q=%23CarpoolHarryoke",
#     "promoted_content": null,
#     "query": "%23CarpoolHarryoke",
#     "tweet_volume": 36876
#    },
#    {
#     "name": "#GreysAnatomy",
#     "url": "http://twitter.com/search?q=%23GreysAnatomy",
#     "promoted_content": null,
#     "query": "%23GreysAnatomy",
#     "tweet_volume": 95782
#    },
#    {
#     "name": "#RipTempo",
#     "url": "http://twitter.com/search?q=%23RipTempo",
#     "promoted_content": null,
#     "query": "%23RipTempo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Supernatural",
#     "url": "http://twitter.com/search?q=%23Supernatural",
#     "promoted_content": null,
#     "query": "%23Supernatural",
#     "tweet_volume": 125418
#    },
#    {
#     "name": "#DEAD",
#     "url": "http://twitter.com/search?q=%23DEAD",
#     "promoted_content": null,
#     "query": "%23DEAD",
#     "tweet_volume": 18802
#    },
#    {
#     "name": "#bucciovertimechallenge",
#     "url": "http://twitter.com/search?q=%23bucciovertimechallenge",
#     "promoted_content": null,
#     "query": "%23bucciovertimechallenge",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InsteadOfComplaining",
#     "url": "http://twitter.com/search?q=%23InsteadOfComplaining",
#     "promoted_content": null,
#     "query": "%23InsteadOfComplaining",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ANAvsNSH",
#     "url": "http://twitter.com/search?q=%23ANAvsNSH",
#     "promoted_content": null,
#     "query": "%23ANAvsNSH",
#     "tweet_volume": 11954
#    },
#    {
#     "name": "#AmazingRace",
#     "url": "http://twitter.com/search?q=%23AmazingRace",
#     "promoted_content": null,
#     "query": "%23AmazingRace",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheBlacklist",
#     "url": "http://twitter.com/search?q=%23TheBlacklist",
#     "promoted_content": null,
#     "query": "%23TheBlacklist",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HelpMeHelpYouOutNow",
#     "url": "http://twitter.com/search?q=%23HelpMeHelpYouOutNow",
#     "promoted_content": null,
#     "query": "%23HelpMeHelpYouOutNow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#masterchefjunior",
#     "url": "http://twitter.com/search?q=%23masterchefjunior",
#     "promoted_content": null,
#     "query": "%23masterchefjunior",
#     "tweet_volume": null
#    },
#    {
#     "name": "#VictoriousFinale",
#     "url": "http://twitter.com/search?q=%23VictoriousFinale",
#     "promoted_content": null,
#     "query": "%23VictoriousFinale",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyMottoShouldBe",
#     "url": "http://twitter.com/search?q=%23MyMottoShouldBe",
#     "promoted_content": null,
#     "query": "%23MyMottoShouldBe",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PiratesLife",
#     "url": "http://twitter.com/search?q=%23PiratesLife",
#     "promoted_content": null,
#     "query": "%23PiratesLife",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AnaheimDucksGoooaaalll",
#     "url": "http://twitter.com/search?q=%23AnaheimDucksGoooaaalll",
#     "promoted_content": null,
#     "query": "%23AnaheimDucksGoooaaalll",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RuinA2000sFilm",
#     "url": "http://twitter.com/search?q=%23RuinA2000sFilm",
#     "promoted_content": null,
#     "query": "%23RuinA2000sFilm",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PDXengage17",
#     "url": "http://twitter.com/search?q=%23PDXengage17",
#     "promoted_content": null,
#     "query": "%23PDXengage17",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MarriedAtFirstSight",
#     "url": "http://twitter.com/search?q=%23MarriedAtFirstSight",
#     "promoted_content": null,
#     "query": "%23MarriedAtFirstSight",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BreakALittle",
#     "url": "http://twitter.com/search?q=%23BreakALittle",
#     "promoted_content": null,
#     "query": "%23BreakALittle",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MAFS2C",
#     "url": "http://twitter.com/search?q=%23MAFS2C",
#     "promoted_content": null,
#     "query": "%23MAFS2C",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-05-19T05:47:18Z",
#   "created_at": "2017-05-19T05:42:05Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#VictoriousFinale', '#Supernatural', 'Ruby Rose', '#DEAD', '#StripThatDown', 'Car Boys', '#GreysAnatomy', '#Scandal', '#NSFW90sShows', '#BuyCryingInTheClubOniTunes', 'Xolos', '#ANAvsNSH', '#bucciovertimechallenge', '#InsteadOfComplaining', '#HelpMeHelpYouOutNow', '#CarpoolHarryoke', '#TheBlacklist', '#RipTempo'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
from urllib.parse import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MentionSomeoneImportantForYou' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except:
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 2
# {
#  "created_at": "Thu May 18 06:17:30 +0000 2017",
#  "id": 865088941153824769,
#  "id_str": "865088941153824769",
#  "text": "RT @juanki_gt: #MentionSomeoneImportantForYou @KadsVega  aunque no me quiera :(",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MentionSomeoneImportantForYou",
#     "indices": [
#      15,
#      45
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "juanki_gt",
#     "name": "Juan Carlos",
#     "id": 358381235,
#     "id_str": "358381235",
#     "indices": [
#      3,
#      13
#     ]
#    },
#    {
#     "screen_name": "KadsVega",
#     "name": "Kadsup",
#     "id": 356460423,
#     "id_str": "356460423",
#     "indices": [
#      46,
#      55
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "es",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 356460423,
#   "id_str": "356460423",
#   "name": "Kadsup",
#   "screen_name": "KadsVega",
#   "location": "",
#   "description": "A tiger never loses sleep over the opinion of sheep.",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 634,
#   "friends_count": 135,
#   "listed_count": 0,
#   "created_at": "Tue Aug 16 22:00:05 +0000 2011",
#   "favourites_count": 375,
#   "utc_offset": -18000,
#   "time_zone": "Central Time (US & Canada)",
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 14141,
#   "lang": "es",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "E08FBA",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/448090924371812352/tlcm7fgZ.jpeg",
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/448090924371812352/tlcm7fgZ.jpeg",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/429736377178017792/g9dd3-Rq_normal.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/429736377178017792/g9dd3-Rq_normal.jpeg",
#   "profile_link_color": "D46062",
#   "profile_sidebar_border_color": "FFFFFF",
#   "profile_sidebar_fill_color": "66072C",
#   "profile_text_color": "F5E7E2",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Wed Mar 27 18:56:18 +0000 2013",
#   "id": 316987059329966080,
#   "id_str": "316987059329966080",
#   "text": "#MentionSomeoneImportantForYou @KadsVega  aunque no me quiera :(",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MentionSomeoneImportantForYou",
#      "indices": [
#       0,
#       30
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "KadsVega",
#      "name": "Kadsup",
#      "id": 356460423,
#      "id_str": "356460423",
#      "indices": [
#       31,
#       40
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 358381235,
#    "id_str": "358381235",
#    "name": "Juan Carlos",
#    "screen_name": "juanki_gt",
#    "location": "Donde karla este \u2600",
#    "description": "Trovador, poeta, guerrillero de las letras, defensor empedernido del et\u00e9reo y sempiterno patriarcado. A veces doy risa.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 261,
#    "friends_count": 124,
#    "listed_count": 0,
#    "created_at": "Fri Aug 19 20:50:41 +0000 2011",
#    "favourites_count": 1568,
#    "utc_offset": -21600,
#    "time_zone": "Mountain Time (US & Canada)",
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 10193,
#    "lang": "es",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/823764043995303937/qQcmS2CY_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/823764043995303937/qQcmS2CY_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/358381235/1481490849",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 2,
#   "favorite_count": 1,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "es"
#  },
#  "is_quote_status": false,
#  "retweet_count": 2,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "es"
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted_status'])

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 23
# {'contributors': None, 'truncated': False, 'text': '#MentionSomeoneImportantForYou God.', 'in_reply_to_status_id': None, 'id': 316944833233186816, 'favorite_count': 0, 'source': 'web', 'retweeted': False, 'coordinates': None, 'entities': {'user_mentions': [], 'hashtags': [{'indices': [0, 30], 'text': 'MentionSomeoneImportantForYou'}], 'urls': []}, 'in_reply_to_screen_name': None, 'in_reply_to_user_id': None, 'retweet_count': 23, 'id_str': '316944833233186816', 'favorited': False, 'user': {'follow_request_sent': None, 'profile_use_background_image': True, 'default_profile_image': False, 'id': 56259379, 'verified': False, 'profile_text_color': '3C3940', 'profile_image_url_https': 'https://si0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', 'profile_sidebar_fill_color': '95E8EC', 'entities': {'url': {'urls': [{'url': 'http://t.co/yRX89YM4J0', 'indices': [0, 22], 'expanded_url': 'http://www.datpiff.com/mixtapes-detail.php?id=470069', 'display_url': 'datpiff.com/mixtapes-detai…'}]}, 'description': {'urls': []}}, 'followers_count': 105041, 'profile_sidebar_border_color': '000000', 'id_str': '56259379', 'profile_background_color': '000000', 'listed_count': 64, 'profile_background_image_url_https': 'https://si0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'utc_offset': -18000, 'statuses_count': 16691, 'description': '#TheseAreTheWordsISaid LP', 'friends_count': 59615, 'location': '', 'profile_link_color': '91785A', 'profile_image_url': 'http://a0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', 'following': None, 'geo_enabled': True, 'profile_banner_url': 'https://si0.twimg.com/profile_banners/56259379/1363388572', 'profile_background_image_url': 'http://a0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'screen_name': 'hassanmusician', 'lang': 'en', 'profile_background_tile': False, 'favourites_count': 6142, 'name': 'Download the NEW LP!', 'notifications': None, 'url': 'http://t.co/yRX89YM4J0', 'created_at': 'Mon Jul 13 02:18:25 +0000 2009', 'contributors_enabled': False, 'time_zone': 'Eastern Time (US & Canada)', 'protected': False, 'default_profile': False, 'is_translator': False}, 'geo': None, 'in_reply_to_user_id_str': None, 'lang': 'en', 'created_at': 'Wed Mar 27 16:08:31 +0000 2013', 'in_reply_to_status_id_str': None, 'place': None, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1) )
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\ud83d\udc4d",
#  "#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.",
#  "RT @hassanmusician: #MentionSomeoneImportantForYou God.",
#  "#MentionSomeoneImportantForYou @Louis_Tomlinson",
#  "#MentionSomeoneImportantForYou @Delta_Universe"
# ]
# [
#  "KathleenMariee_",
#  "AhhlicksCruise",
#  "itsravennn_cx",
#  "kandykisses_13",
#  "BMOLOGY"
# ]
# [
#  "MentionSomeOneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou"
# ]
# [
#  "\u201c@KathleenMariee_:",
#  "#MentionSomeOneImportantForYou",
#  "@AhhlicksCruise",
#  ",",
#  "@itsravennn_cx"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#MentionSomeoneImportantForYou', 92), ('RT', 34), ('my', 10), (',', 6), ('&lt;3', 6), ('@justinbieber', 6), ('My', 5), ('I', 4), ('and', 4), ('love', 3)]
# [('justinbieber', 6), ('Cavillafuerte', 2), ('Kid_Charliej', 2), ('KathleenMariee_', 1), ('AhhlicksCruise', 1), ('itsravennn_cx', 1), ('kandykisses_13', 1), ('BMOLOGY', 1), ('Linkin_Sunrise', 1), ('hassanmusician', 1)]
# [('MentionSomeoneImportantForYou', 94), ('mentionsomeoneimportantforyou', 3), ('MentionSomeOneImportantForYou', 1), ('NoHomo', 1), ('bebesito', 1), ('MyHeart', 1), ('Love', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
# !pip3 install prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-0.7.2.zip
# Building wheels for collected packages: prettytable
#   Running setup.py bdist_wheel for prettytable ... done
#   Stored in directory: /Users/rdalanist/Library/Caches/pip/wheels/b6/90/7b/1c22b89217d0eba6d5f406e562365ebee804f0d4595b2bdbcd
# Successfully built prettytable
# Installing collected packages: prettytable
# Successfully installed prettytable-0.7.2

# %%
#Maybe usamos pandas?

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +--------------------------------+-------+
# | Word                           | Count |
# +--------------------------------+-------+
# | #MentionSomeoneImportantForYou |    92 |
# | RT                             |    34 |
# | my                             |    10 |
# | ,                              |     6 |
# | &lt;3                          |     6 |
# | @justinbieber                  |     6 |
# | My                             |     5 |
# | I                              |     4 |
# | and                            |     4 |
# | love                           |     3 |
# +--------------------------------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | justinbieber    |     6 |
# | Cavillafuerte   |     2 |
# | Kid_Charliej    |     2 |
# | KathleenMariee_ |     1 |
# | AhhlicksCruise  |     1 |
# | itsravennn_cx   |     1 |
# | kandykisses_13  |     1 |
# | BMOLOGY         |     1 |
# | Linkin_Sunrise  |     1 |
# | hassanmusician  |     1 |
# +-----------------+-------+
# +-------------------------------+-------+
# | Hashtag                       | Count |
# +-------------------------------+-------+
# | MentionSomeoneImportantForYou |    94 |
# | mentionsomeoneimportantforyou |     3 |
# | MentionSomeOneImportantForYou |     1 |
# | NoHomo                        |     1 |
# | bebesito                      |     1 |
# | MyHeart                       |     1 |
# | Love                          |     1 |
# +-------------------------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.6761061946902654
# 0.9554140127388535
# 0.06862745098039216
# 5.76530612244898

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 23    | hassanmusician | RT @hassanmusician: #MentionSomeoneImportantForYou |
# |       |                | God.                                               |
# | 21    | HSweethearts   | RT @HSweethearts: #MentionSomeoneImportantForYou   |
# |       |                | my high school sweetheart ❤💋                       |
# | 15    | LosAlejandro_  | RT @LosAlejandro_: ¿Nadie te menciono en           |
# |       |                | "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJA |
# |       |                | JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...  |
# | 9     | SCOTTSUMME     | RT @SCOTTSUMME: #MentionSomeoneImportantForYou My  |
# |       |                | Mum. Shes loving, caring, strong, all in one. I    |
# |       |                | love her so much ❤❤❤❤                              |
# | 7     | degrassihaha   | RT @degrassihaha: #MentionSomeoneImportantForYou I |
# |       |                | can't put every Degrassi cast member, crew member, |
# |       |                | and writer in just one tweet....                   |
# +-------+----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print([r['user']['screen_name'] for r in _retweets])
# Out:
# ['jyeee', 'Ceejaynatics', 'ikaayyy_', 'RafaellaaaMae', 'LoveKyana18', 'iiaamcamillee', 'kidamgos', 'asdfghjbl', 'Papagars__', 'josellexseraspi', 'annegabriellee_']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(list(c.values()))
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [23, 1, 21, 1, 5, 2, 2, 2, 3, 1, 1, 1, 1, 9, 1, 1, 1, 15, 1, 1, 1, 2, 1, 1, 7, 6, 1, 3, 1, 1, 1, 1, 1]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
from math import log

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(len(counts)))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print(log(len(counts)))
# Out:
# 3.4965075614664802
